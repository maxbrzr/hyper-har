# %%
from whar_datasets import (
    Loader,
    LOSOSplitter,
    PostProcessingPipeline,
    PreProcessingPipeline,
    TorchAdapter,
    WHARDatasetID,
    get_dataset_cfg,
)

# create cfg for WISDM dataset
cfg = get_dataset_cfg(WHARDatasetID.WEAR, datasets_dir="../datasets")

# create and run pre-processing pipeline
pre_pipeline = PreProcessingPipeline(cfg)
activity_df, session_df, window_df = pre_pipeline.run()

# create LOSO splits
splitter = LOSOSplitter(cfg)
splits = splitter.get_splits(session_df, window_df)
split = splits[0]

# create and run post-processing pipeline for the specific split
post_pipeline = PostProcessingPipeline(
    cfg, pre_pipeline, window_df, split.train_indices
)
samples = post_pipeline.run()

# create dataloaders for the specific split
loader = Loader(session_df, window_df, post_pipeline.samples_dir, samples)
adapter = TorchAdapter(cfg, loader, split)
dataloaders = adapter.get_dataloaders(batch_size=64)
# Out:
# /Users/maxburzer/hyper-har/.venv/lib/python3.12/site-packages/whar_datasets/config/cfg_hugadb.py:40: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv(full_path, sep="\s+", skiprows=3)
# 2026-05-05 16:54:19,514 - whar-datasets - INFO - Running DownloadingStep
# 2026-05-05 16:54:19,515 - whar-datasets - INFO - Checking hash for DownloadingStep
# 2026-05-05 16:54:19,515 - whar-datasets - INFO - Hash is up to date
# 2026-05-05 16:54:19,516 - whar-datasets - INFO - Running ExtractingStep
# 2026-05-05 16:54:19,516 - whar-datasets - INFO - Checking hash for ExtractingStep
# 2026-05-05 16:54:19,516 - whar-datasets - INFO - Hash is up to date
# 2026-05-05 16:54:19,517 - whar-datasets - INFO - Running ParsingStep
# 2026-05-05 16:54:19,517 - whar-datasets - INFO - Checking hash for ParsingStep
# 2026-05-05 16:54:19,517 - whar-datasets - INFO - Hash is up to date
# 2026-05-05 16:54:19,517 - whar-datasets - INFO - Running WindowingStep
# 2026-05-05 16:54:19,518 - whar-datasets - INFO - Checking hash for WindowingStep
# 2026-05-05 16:54:19,518 - whar-datasets - INFO - Hash is not up to date
# 2026-05-05 16:54:19,521 - whar-datasets - INFO - Validating common format
# 2026-05-05 16:54:19,540 - whar-datasets - INFO - Validating sessions (parallelized)
# Validating sessions (dask): 2it [00:03,  1.59s/it]
# 2026-05-05 16:54:22,726 - whar-datasets - INFO - Common format validated.
# 2026-05-05 16:54:22,726 - whar-datasets - INFO - Compute windowing
# 2026-05-05 16:54:22,727 - whar-datasets - INFO - Selecting activities
# 2026-05-05 16:54:22,734 - whar-datasets - INFO - Processing sessions (parallelized)
# Processing sessions (dask): 439it [00:15, 28.03it/s]
# 2026-05-05 16:54:38,413 - whar-datasets - INFO - Saving windowing
# 2026-05-05 16:54:46,241 - whar-datasets - INFO - Loading windowing
# 2026-05-05 16:54:46,257 - whar-datasets - INFO - Selecting activities
# 2026-05-05 16:54:46,260 - whar-datasets - INFO - activity_ids from 0 to 17
# 2026-05-05 16:54:46,261 - whar-datasets - INFO - subject_ids from 0 to 23
# 2026-05-05 16:54:46,377 - whar-datasets - INFO - Running SamplingStep
# 2026-05-05 16:54:46,378 - whar-datasets - INFO - Checking hash for SamplingStep
# 2026-05-05 16:54:46,379 - whar-datasets - INFO - Hash is not up to date
# 2026-05-05 16:54:51,600 - whar-datasets - INFO - Computing samples
# 2026-05-05 16:54:51,601 - whar-datasets - INFO - Getting normalization parameters
# 2026-05-05 16:54:52,454 - whar-datasets - INFO - Normalizing and transforming windows (parallelized)
# Preparing windows (dask): 40435it [00:27, 1481.58it/s]
# 2026-05-05 16:55:19,768 - whar-datasets - INFO - Saving samples
# 2026-05-05 16:55:20,068 - whar-datasets - INFO - Loading samples
